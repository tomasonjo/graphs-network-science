# %%
# !pip install pykeen==1.10.1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pykeen==1.10.1 in /usr/local/lib/python3.10/dist-packages (1.10.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from pykeen==1.10.1) (8.1.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pykeen==1.10.1) (1.22.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from pykeen==1.10.1) (1.2.2)
# Requirement already satisfied: torch>=1.10 in /usr/local/lib/python3.10/dist-packages (from pykeen==1.10.1) (2.0.0+cu118)
# Requirement already satisfied: pystow>=0.4.3 in /usr/local/lib/python3.10/dist-packages (from pykeen==1.10.1) (0.5.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from pykeen==1.10.1) (2.27.1)
# Requirement already satisfied: dataclasses-json in /usr/local/lib/python3.10/dist-packages (from pykeen==1.10.1) (0.5.7)
# Requirement already satisfied: docdata in /usr/local/lib/python3.10/dist-packages (from pykeen==1.10.1) (0.0.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from pykeen==1.10.1) (4.5.0)
# Requirement already satisfied: torch-ppr>=0.0.7 in /usr/local/lib/python3.10/dist-packages (from pykeen==1.10.1) (0.0.8)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from pykeen==1.10.1) (6.0)
# Requirement already satisfied: torch-max-mem>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from pykeen==1.10.1) (0.0.5)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.10/dist-packages (from pykeen==1.10.1) (9.1.0)
# Requirement already satisfied: class-resolver>=0.3.10 in /usr/local/lib/python3.10/dist-packages (from pykeen==1.10.1) (0.4.2)
# Requirement already satisfied: more-click in /usr/local/lib/python3.10/dist-packages (from pykeen==1.10.1) (0.1.2)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from pykeen==1.10.1) (0.8.10)
# Requirement already satisfied: protobuf<4.0.0 in /usr/local/lib/python3.10/dist-packages (from pykeen==1.10.1) (3.20.3)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from pykeen==1.10.1) (1.5.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from pykeen==1.10.1) (4.65.0)
# Requirement already satisfied: optuna>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from pykeen==1.10.1) (3.1.1)
# Requirement already satisfied: click-default-group in /usr/local/lib/python3.10/dist-packages (from pykeen==1.10.1) (1.2.2)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from pykeen==1.10.1) (1.10.1)
# Requirement already satisfied: rexmex>=0.1.3 in /usr/local/lib/python3.10/dist-packages (from pykeen==1.10.1) (0.1.3)
# Requirement already satisfied: cmaes>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from optuna>=2.0.0->pykeen==1.10.1) (0.9.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna>=2.0.0->pykeen==1.10.1) (23.1)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.10/dist-packages (from optuna>=2.0.0->pykeen==1.10.1) (6.7.0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from optuna>=2.0.0->pykeen==1.10.1) (1.10.4)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna>=2.0.0->pykeen==1.10.1) (2.0.10)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.0->pykeen==1.10.1) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.0->pykeen==1.10.1) (2.8.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10->pykeen==1.10.1) (3.1.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10->pykeen==1.10.1) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10->pykeen==1.10.1) (3.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.10->pykeen==1.10.1) (3.12.0)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10->pykeen==1.10.1) (2.0.0)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.10->pykeen==1.10.1) (16.0.2)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.10->pykeen==1.10.1) (3.25.2)
# Requirement already satisfied: typing-inspect>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json->pykeen==1.10.1) (0.8.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json->pykeen==1.10.1) (3.19.0)
# Requirement already satisfied: marshmallow-enum<2.0.0,>=1.5.1 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json->pykeen==1.10.1) (1.5.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->pykeen==1.10.1) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->pykeen==1.10.1) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->pykeen==1.10.1) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->pykeen==1.10.1) (2022.12.7)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->pykeen==1.10.1) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->pykeen==1.10.1) (3.1.0)
# Requirement already satisfied: Mako in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna>=2.0.0->pykeen==1.10.1) (1.2.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1.0.0->pykeen==1.10.1) (1.16.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna>=2.0.0->pykeen==1.10.1) (2.0.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from typing-inspect>=0.4.0->dataclasses-json->pykeen==1.10.1) (1.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10->pykeen==1.10.1) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10->pykeen==1.10.1) (1.3.0)

# %%
import pandas as pd

data = pd.read_csv(
    "https://bit.ly/3X2qp1r"
)
data.head()
# Out:
#   source_name source_label target_name target_label       type
# 0    SERPINF2         Gene       KLK13         Gene  interacts
# 1    SERPINF2         Gene        SSR1         Gene  interacts
# 2    SERPINF2         Gene        TGM2         Gene  interacts
# 3    SERPINF2         Gene         UBC         Gene  interacts
# 4    SERPINF2         Gene   SERPINB12         Gene  interacts

# %%
data["type"].unique()
# Out:
# array(['interacts', 'regulates', 'covaries', 'upregulates', 'binds',
#        'downregulates', 'resembles', 'associates', 'treats'], dtype=object)

# %%
from pykeen.triples import TriplesFactory

tf = TriplesFactory.from_labeled_triples(
    data[["source_name", "type", "target_name"]].values,
)
# Out:
# INFO:pykeen.utils:Using opt_einsum

# %%
training, testing, validation = tf.split([0.8, 0.1, 0.1], random_state=0)
# Out:
# INFO:pykeen.triples.splitting:done splitting triples to groups of sizes [430312, 56172, 56172]

# %%
from pykeen.pipeline import pipeline

result = pipeline(
    training=training,
    testing=testing,
    validation=validation,
    model="PairRE",
    stopper="early",
    epochs=100,
    random_seed=0,
)
# Out:
# INFO:pykeen.pipeline.api:Using device: None
# INFO:pykeen.stoppers.early_stopping:Inferred checkpoint path for best model weights: /root/.data/pykeen/checkpoints/best-model-weights-365fea85-928d-4877-a6a5-bb4946283ef6.pt
# Training epochs on cuda:0:   0%|          | 0/100 [00:00<?, ?epoch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# INFO:pykeen.evaluation.evaluator:Starting batch_size search for evaluation now...
# INFO:pykeen.evaluation.evaluator:Concluded batch_size search with batch_size=128.
# INFO:pykeen.evaluation.evaluator:Evaluation took 59.52s seconds
# INFO:pykeen.stoppers.early_stopping:New best result at epoch 10: 0.038328704692729476. Saved model weights to /root/.data/pykeen/checkpoints/best-model-weights-365fea85-928d-4877-a6a5-bb4946283ef6.pt
# INFO:pykeen.training.training_loop:=> Saved checkpoint after having finished epoch 10.
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# INFO:pykeen.evaluation.evaluator:Evaluation took 59.67s seconds
# INFO:pykeen.stoppers.early_stopping:New best result at epoch 20: 0.044728690450758384. Saved model weights to /root/.data/pykeen/checkpoints/best-model-weights-365fea85-928d-4877-a6a5-bb4946283ef6.pt
# INFO:pykeen.training.training_loop:=> Saved checkpoint after having finished epoch 20.
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# INFO:pykeen.evaluation.evaluator:Evaluation took 59.86s seconds
# INFO:pykeen.stoppers.early_stopping:New best result at epoch 30: 0.04798654133732109. Saved model weights to /root/.data/pykeen/checkpoints/best-model-weights-365fea85-928d-4877-a6a5-bb4946283ef6.pt
# INFO:pykeen.training.training_loop:=> Saved checkpoint after having finished epoch 30.
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# INFO:pykeen.evaluation.evaluator:Evaluation took 59.69s seconds
# INFO:pykeen.stoppers.early_stopping:New best result at epoch 40: 0.04869863989176102. Saved model weights to /root/.data/pykeen/checkpoints/best-model-weights-365fea85-928d-4877-a6a5-bb4946283ef6.pt
# INFO:pykeen.training.training_loop:=> Saved checkpoint after having finished epoch 40.
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# INFO:pykeen.evaluation.evaluator:Evaluation took 60.56s seconds
# INFO:pykeen.stoppers.early_stopping:New best result at epoch 50: 0.05178736737164424. Saved model weights to /root/.data/pykeen/checkpoints/best-model-weights-365fea85-928d-4877-a6a5-bb4946283ef6.pt
# INFO:pykeen.training.training_loop:=> Saved checkpoint after having finished epoch 50.
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# INFO:pykeen.evaluation.evaluator:Evaluation took 59.48s seconds
# INFO:pykeen.stoppers.early_stopping:New best result at epoch 60: 0.05282881150751264. Saved model weights to /root/.data/pykeen/checkpoints/best-model-weights-365fea85-928d-4877-a6a5-bb4946283ef6.pt
# INFO:pykeen.training.training_loop:=> Saved checkpoint after having finished epoch 60.
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# INFO:pykeen.evaluation.evaluator:Evaluation took 59.43s seconds
# INFO:pykeen.stoppers.early_stopping:New best result at epoch 70: 0.055338958911913406. Saved model weights to /root/.data/pykeen/checkpoints/best-model-weights-365fea85-928d-4877-a6a5-bb4946283ef6.pt
# INFO:pykeen.training.training_loop:=> Saved checkpoint after having finished epoch 70.
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# INFO:pykeen.evaluation.evaluator:Evaluation took 59.47s seconds
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# INFO:pykeen.evaluation.evaluator:Evaluation took 59.60s seconds
# INFO:pykeen.stoppers.early_stopping:New best result at epoch 90: 0.056246884568824325. Saved model weights to /root/.data/pykeen/checkpoints/best-model-weights-365fea85-928d-4877-a6a5-bb4946283ef6.pt
# INFO:pykeen.training.training_loop:=> Saved checkpoint after having finished epoch 90.
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/1756 [00:00<?, ?batch/s]
# INFO:pykeen.evaluation.evaluator:Evaluation took 60.00s seconds
# Evaluating on cuda:0:   0%|          | 0.00/56.2k [00:00<?, ?triple/s]
# INFO:pykeen.evaluation.evaluator:Evaluation took 62.07s seconds

# %%
from pykeen.predict import predict_target

pred = predict_target(
    result.model,
    head="Acetylsalicylic acid",
    relation="treats",
    triples_factory=result.training,
).df
print(pred.head())
# Out:
#        tail_id     score                    tail_label
# 19835    19835 -9.078091       coronary artery disease
# 19912    19912 -9.228726  systemic lupus erythematosus
# 19827    19827 -9.510363                 breast cancer
# 19913    19913 -9.543921          systemic scleroderma
# 19887    19887 -9.711681             pancreatic cancer
